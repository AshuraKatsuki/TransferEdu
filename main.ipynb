# %%
# !pip install pytesseract
# !pip install google-genai

# %%
import os 
import base64
import os
from google import genai
from google.genai import types
from dotenv import load_dotenv
from mistralai import Mistral

# %%
load_dotenv()

client = Mistral(api_key = '8gKDvv9jlEsUsNDce70tXPLhO6f01Ehr')

# %%
uploaded_file = client.files.upload(
    file = {
        'file_name': 'U1170655.pdf',
        'content': open('U1170655.pdf', 'rb')
    },
    purpose = 'ocr'
)

# %%
file_url = client.files.get_signed_url(file_id = uploaded_file.id)

# %%
response = client.ocr.process(
    model = 'mistral-ocr-latest',
    document = { 
        'type': 'document_url',
        'document_url': file_url.url
    },
    include_image_base64 = True,
)

# %%
def data_uri_to_bytes(data_uri):
    _, encoded = data_uri.split(',', 1)
    return base64.b64decode(encoded)

def export_image(image):
    parsed_image = data_uri_to_bytes(image.image_base64)
    with open(image.id, 'wb') as file: 
        file.write(parsed_image)

with open('output.md', 'w') as f:
    for page in response.pages:
        f.write(page.markdown)
        for image in page.images: 
            export_image(image)

# %%
# Gemini Large Language Model
def generate():
    client = genai.Client(
        api_key= "AIzaSyAQe-j4N3eJGe6fUxR6rX5_A8dUULtzZuo",
    )

    model = "gemini-2.0-flash"
    file_path = "output.md"
    if not os.path.exists(file_path):
        print(f"Error: Not Found {file_path}")
        return

    with open(file_path, "r", encoding="utf-8") as f:
        document_content = f.read()

    prompt_instruction = "tóm tắt văn bản"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text=prompt_instruction),
                types.Part.from_text(text=document_content),
            ],
        ),
    ]

    # tools = [
    #     types.Tool(googleSearch=types.GoogleSearch(
    #     )),
    # ]

    generate_content_config = types.GenerateContentConfig(
        # tools=tools,
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

# %%
generate()
# Out:
# Báo cáo đánh giá sản phẩm phần mềm này đánh giá SoundCloud, một nền tảng phát nhạc trực tuyến phổ biến. SoundCloud cho phép nghệ sĩ tải lên, chia sẻ và quảng bá âm nhạc, đồng thời cho phép người dùng khám phá các bài hát và nghệ sĩ yêu thích. Nó hướng đến đối tượng trẻ tuổi và là một phần mềm chung, được cập nhật thường xuyên.
#
# Các tính năng chính của SoundCloud bao gồm tải lên và chia sẻ nhạc, cho phép người dùng bình luận theo thời gian cụ thể và đề xuất bài hát dựa trên sở thích của người dùng. SoundCloud cạnh tranh với Spotify và YouTube Music, nhưng tập trung vào các nghệ sĩ độc lập và mới nổi, nhấn mạnh khả năng tương tác cộng đồng thông qua tính năng bình luận.
#
# Người dùng chính của SoundCloud là các nghệ sĩ độc lập, DJ và podcaster. Nền tảng này cũng phục vụ người nghe nhạc và cung cấp các gói đăng ký trả phí.
#
# ...
